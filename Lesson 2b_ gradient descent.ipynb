# %% [markdown]
# # This lesson is available on github
#
# - Lesson: https://github.com/aviadr1/deep-learning-notebooks
#
# > The lesson requires some interactive elements that work well in jupyterlab but not on colab
